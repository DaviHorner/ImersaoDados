# %% [markdown]
# <a href="https://colab.research.google.com/github/DaviHorner/ImersaoDados/blob/master/Aula-01/Desafios_Aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Preparar dados

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# A classe tratamento é dividida em quando se usa drogas e quando se está no controle, por isso dá essa disparidade em valores, pois apenas uma das drogas utilizadas pertence ao grupo de controle.

# %%
dados[['tratamento','droga']].value_counts()
# Out:
# tratamento    droga
# com_controle  cacb2b860    1866
# com_droga     87d714366     718
#               9f80f3f77     246
#               8b87a7a83     203
#               5628cb3ee     202
#                            ...
#               b3f24a171       1
#               1502f8cbb       1
#               36dc71f82       1
#               b472193a9       1
#               547f80a41       1
# Length: 3289, dtype: int64

# %% [markdown]
# ###DEsafio 02: Plotar as 5 últimas linhas da tabela

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 03: Proporção das classes tratamento.

# %%
dados['tratamento'].value_counts().plot.bar()

# %% [markdown]
# ###Desafio 04: Quantas tipos de drogas foram investigados.

# %%
dados['droga'].unique
# Out:
# <bound method Series.unique of 0        b68db1d53
# 1        df89a8e5a
# 2        18bb41b2c
# 3        8c7f86626
# 4        7cbed3131
#            ...
# 23809    df1d0a5a1
# 23810    ecf3b6b74
# 23811    cacb2b860
# 23812    8b87a7a83
# 23813    972f41291
# Name: droga, Length: 23814, dtype: object>

# %% [markdown]
# ###Desafio 05: Procurar na documentação o método query(pandas).

# %%
dados.query('tempo > 48').tempo.count()
# Out:
# 7792

# %% [markdown]
# ###Desafio 06: Renomear as colunas tirando o hífen.

# %%
dados.columns = dados.columns.str.replace('-','')

# %% [markdown]
# ###Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)

# %%
import matplotlib.pyplot as plt

tempo = dados.tempo.value_counts()
label = dados.tempo.unique()
explode = (0, 0.1, 0)
plt.title("Tempo")

labels = dados.tempo
plt.pie(tempo, labels = label, shadow = True, explode = explode, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd10f5c3710>,
# ...
#  [Text(0.5103354069322461, 0.9744525501179105, '24'),
#   Text(-1.197614947337226, -0.07562035383713542, '72'),
#   Text(0.570728131779082, -0.9403559962035437, '48')],
#  [Text(0.27836476741758875, 0.5315195727915875, '34.6%'),
#   Text(-0.6986087192800485, -0.04411187307166232, '32.7%'),
#   Text(0.31130625369768106, -0.5129214524746601, '32.6%')])

# %% [markdown]
# ###Desafio 08: Resumo do que você aprendeu com os dados
#
# Eu aprendi que o nome
